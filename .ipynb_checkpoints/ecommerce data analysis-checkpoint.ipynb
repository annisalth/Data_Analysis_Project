# %% [markdown]
# # Proyek Analisis Data :

# %% [markdown]
# ### Nama: Annisa Luthfi Nabilah
# ### Email: m004d4kx2581@bangkit.academy
# ### ID Dicoding: annisaluthfin

# %% [markdown]
# # Pertanyaan Bisnis :

# %% [markdown]
# ### 1. Kategori produk apa saja yang paling banyak dan yang paling sedikit dipesan?
# ### 2. Bagaimana segmentasi pada pelanggan berdasarkan Recency (R), Frequency (F), dan Monetary(M)?
# ### 3. Dimana letak geografis yang memiliki customer terbanyak?

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# pip install streamlit

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %%
#Mengambil data customer 
customers_df = pd.read_csv('customers_dataset.csv')
customers_df
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 5 columns]

# %%
# Mengambil dan menampilkan data produk
df_products = pd.read_csv('products_dataset.csv')
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# 1                     44.0                       276.0                 1.0
# 2                     46.0                       250.0                 1.0
# 3                     27.0                       261.0                 1.0
# 4                     37.0                       402.0                 4.0
# ...                    ...                         ...                 ...
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# 1                1000.0               30.0               18.0
# 2                 154.0               18.0                9.0
# 3                 371.0               26.0                4.0
# 4                 625.0               20.0               17.0
# ...                 ...                ...                ...
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm
# 0                  14.0
# 1                  20.0
# 2                  15.0
# 3                  26.0
# 4                  13.0
# ...                 ...
# 32946              40.0
# 32947              16.0
# 32948              27.0
# 32949              20.0
# 32950               7.0
#
# [32951 rows x 9 columns]

# %%
# Mengambil dan menampilkan data order item 
df_order_item = pd.read_csv('order_items_dataset.csv')
df_order_item
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 7 columns]

# %%
# Mengambil dan menampilkan data order 
df_orders = pd.read_csv('orders_dataset.csv')
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
# Mengambil dan menampilkan data seller 
sellers_df = pd.read_csv('sellers_dataset.csv')
sellers_df
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 4 columns]

# %%
# Mengambil dan menampilkan data kategori produk 
products_translate_df = pd.read_csv('product_category_name_translation.csv')
products_translate_df
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
geo_df = pd.read_csv('geolocation_dataset.csv')
geo_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Melakukan joining kedua tabel orders_df dan customers_df
# tujuan : memperoleh satu DataFrame yang berisi informasi tentang pesanan serta informasi pelanggan yang melakukan transaksi

joined_df1 = pd.merge(
    left=df_orders,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
print('Jumlah baris dan kolom pada joined_df1:', joined_df1.shape)
joined_df1.head()
# Out:
# Jumlah baris dan kolom pada joined_df1: (99441, 12)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date                customer_unique_id  \
# 0           2017-10-18 00:00:00  7c396fd4830fd04220f754e42b4e5bff
# 1           2018-08-13 00:00:00  af07308b275d755c9edb36a90c618231
# 2           2018-09-04 00:00:00  3a653a41f6f9fc3d2a113cf8398680e8
# 3           2017-12-15 00:00:00  7c142cf63193a1473d2e66489a9ae977
# 4           2018-02-26 00:00:00  72632f0f9dd73dfee390c9b22eb56dd6
#
#    customer_zip_code_prefix            customer_city customer_state
# 0                      3149                sao paulo             SP
# 1                     47813                barreiras             BA
# 2                     75265               vianopolis             GO
# 3                     59296  sao goncalo do amarante             RN
# 4                      9195              santo andre             SP

# %%
# Melakukan joining keempat tabel order_items_df, sellers_df, products_df, dan products_translate_df
# Tujuannya untuk dapat melihat informasi yang lebih lengkap tentang setiap item pesanan, termasuk informasi tentang penjual, produk, dan kategori produk. Dengan melakukan join ini, kita dapat memperoleh satu DataFrame yang berisi detail informasi tentang setiap item pesanan.

joined_df2 = pd.merge(
    pd.merge( 
        df_order_item, sellers_df,
        how = "left", on='seller_id'
        ),
    pd.merge( 
        df_products, products_translate_df,
        how = "left",
        on='product_category_name'
        ),
    how="left",
    on="product_id"
    )
print('Jumlah baris dan kolom pada joined_df2:', joined_df2.shape)
joined_df2.head()
# Out:
# Jumlah baris dan kolom pada joined_df2: (112650, 19)
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0  2017-09-19 09:45:35   58.90          13.29                   27277
# 1  2017-05-03 11:05:13  239.90          19.93                    3471
# 2  2018-01-18 14:48:30  199.00          17.87                   37564
# 3  2018-08-15 10:10:18   12.99          12.79                   14403
# 4  2017-02-13 13:57:51  199.90          18.14                   87900
#
#      seller_city seller_state product_category_name  product_name_lenght  \
# 0  volta redonda           SP            cool_stuff                 58.0
# 1      sao paulo           SP              pet_shop                 56.0
# 2  borda da mata           MG      moveis_decoracao                 59.0
# 3         franca           SP            perfumaria                 42.0
# 4         loanda           PR    ferramentas_jardim                 59.0
#
#    product_description_lenght  product_photos_qty  product_weight_g  \
# 0                       598.0                 4.0             650.0
# 1                       239.0                 2.0           30000.0
# 2                       695.0                 2.0            3050.0
# 3                       480.0                 1.0             200.0
# 4                       409.0                 1.0            3750.0
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0               28.0                9.0              14.0
# 1               50.0               30.0              40.0
# 2               33.0               13.0              33.0
# 3               16.0               10.0              15.0
# 4               35.0               40.0              30.0
#
#   product_category_name_english
# 0                    cool_stuff
# 1                      pet_shop
# 2               furniture_decor
# 3                     perfumery
# 4                  garden_tools

# %% [markdown]
# ## Assessing Data

# %%
# Mengecek duplikasi data dan melihat info tabel joined_df1
print('Jumlah duplikasi data : ', joined_df1.duplicated().sum())
joined_df1.info()
# Out:
# Jumlah duplikasi data :  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
#  8   customer_unique_id             99441 non-null  object
#  9   customer_zip_code_prefix       99441 non-null  int64
#  10  customer_city                  99441 non-null  object
#  11  customer_state                 99441 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 9.1+ MB

# %% [markdown]
# Tabel tidak terdapat duplikasi data
# Data tidak lengkap pada beberapa kolom
# Terdapat kesalahan tipe data

# %%
# Cek jumlah missing value pada tabel orders_df
joined_df1.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# dtype: int64

# %% [markdown]
# Terdapat missing value pada kolom tanggal.

# %%
# Melihat deskripsi statistik tabel joined_df1
joined_df1.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
# mean            NaN                      NaN                  NaN
# std             NaN                      NaN                  NaN
# min             NaN                      NaN                  NaN
# 25%             NaN                      NaN                  NaN
# 50%             NaN                      NaN                  NaN
# 75%             NaN                      NaN                  NaN
# max             NaN                      NaN                  NaN
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-08 23:38:46
# freq                             47                             3
# mean                            NaN                           NaN
# std                             NaN                           NaN
# min                             NaN                           NaN
# 25%                             NaN                           NaN
# 50%                             NaN                           NaN
# 75%                             NaN                           NaN
# max                             NaN                           NaN
#
#        order_estimated_delivery_date                customer_unique_id  \
# count                          99441                             99441
# unique                           459                             96096
# top              2017-12-20 00:00:00  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                             522                                17
# mean                             NaN                               NaN
# std                              NaN                               NaN
# min                              NaN                               NaN
# 25%                              NaN                               NaN
# 50%                              NaN                               NaN
# 75%                              NaN                               NaN
# max                              NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %%
# Cek duplikasi data dan melihat info tabel joined_df2
print('Jumlah duplikasi data: ', joined_df2.duplicated().sum())
joined_df2.info()
# Out:
# Jumlah duplikasi data:  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  object
#  3   seller_id                      112650 non-null  object
#  4   shipping_limit_date            112650 non-null  object
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   seller_zip_code_prefix         112650 non-null  int64
#  8   seller_city                    112650 non-null  object
#  9   seller_state                   112650 non-null  object
#  10  product_category_name          111047 non-null  object
#  11  product_name_lenght            111047 non-null  float64
#  12  product_description_lenght     111047 non-null  float64
#  13  product_photos_qty             111047 non-null  float64
#  14  product_weight_g               112632 non-null  float64
#  15  product_length_cm              112632 non-null  float64
#  16  product_height_cm              112632 non-null  float64
#  17  product_width_cm               112632 non-null  float64
#  18  product_category_name_english  111023 non-null  object
# dtypes: float64(9), int64(2), object(8)
# memory usage: 16.3+ MB

# %% [markdown]
# Tidak terdapat duplikasi data
# Data tidak lengkap pada beberapa kolom

# %%
# Cek jumlah missing value pada tabel joined_df2
joined_df2.isna().sum()
# Out:
# order_id                            0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# seller_zip_code_prefix              0
# seller_city                         0
# seller_state                        0
# product_category_name            1603
# product_name_lenght              1603
# product_description_lenght       1603
# product_photos_qty               1603
# product_weight_g                   18
# product_length_cm                  18
# product_height_cm                  18
# product_width_cm                   18
# product_category_name_english    1627
# dtype: int64

# %%
#Melihat deskripsi statistik tabel joined_df2
joined_df2.describe(include='all').transpose()
# Out:
#                                   count unique  \
# order_id                         112650  98666
# order_item_id                  112650.0    NaN
# product_id                       112650  32951
# seller_id                        112650   3095
# shipping_limit_date              112650  93318
# price                          112650.0    NaN
# freight_value                  112650.0    NaN
# seller_zip_code_prefix         112650.0    NaN
# seller_city                      112650    611
# seller_state                     112650     23
# product_category_name            111047     73
# product_name_lenght            111047.0    NaN
# product_description_lenght     111047.0    NaN
# product_photos_qty             111047.0    NaN
# product_weight_g               112632.0    NaN
# product_length_cm              112632.0    NaN
# product_height_cm              112632.0    NaN
# product_width_cm               112632.0    NaN
# product_category_name_english    111023     71
#
#                                                             top   freq  \
# order_id                       8272b63d03f5f79c56e9e4120aec44ef     21
# order_item_id                                               NaN    NaN
# product_id                     aca2eb7d00ea1a7b8ebd4e68314663af    527
# seller_id                      6560211a19b47992c3666cc44a7e94c0   2033
# shipping_limit_date                         2017-07-21 18:25:23     21
# price                                                       NaN    NaN
# freight_value                                               NaN    NaN
# seller_zip_code_prefix                                      NaN    NaN
# seller_city                                           sao paulo  27983
# seller_state                                                 SP  80342
# product_category_name                           cama_mesa_banho  11115
# product_name_lenght                                         NaN    NaN
# product_description_lenght                                  NaN    NaN
# product_photos_qty                                          NaN    NaN
# product_weight_g                                            NaN    NaN
# product_length_cm                                           NaN    NaN
# product_height_cm                                           NaN    NaN
# product_width_cm                                            NaN    NaN
# product_category_name_english                    bed_bath_table  11115
#
#                                        mean           std     min     25%  \
# order_id                                NaN           NaN     NaN     NaN
# order_item_id                      1.197834      0.705124     1.0     1.0
# product_id                              NaN           NaN     NaN     NaN
# seller_id                               NaN           NaN     NaN     NaN
# shipping_limit_date                     NaN           NaN     NaN     NaN
# price                            120.653739    183.633928    0.85    39.9
# freight_value                      19.99032     15.806405     0.0   13.08
# seller_zip_code_prefix         24439.170431  27596.030909  1001.0  6429.0
# seller_city                             NaN           NaN     NaN     NaN
# seller_state                            NaN           NaN     NaN     NaN
# product_category_name                   NaN           NaN     NaN     NaN
# product_name_lenght               48.775978     10.025581     5.0    42.0
# product_description_lenght       787.867029    652.135608     4.0   348.0
# product_photos_qty                 2.209713      1.721438     1.0     1.0
# product_weight_g                2093.672047   3751.596884     0.0   300.0
# product_length_cm                 30.153669     16.153449     7.0    18.0
# product_height_cm                 16.593766     13.443483     2.0     8.0
# product_width_cm                  22.996546     11.707268     6.0    15.0
# product_category_name_english           NaN           NaN     NaN     NaN
#
#                                    50%      75%      max
# order_id                           NaN      NaN      NaN
# order_item_id                      1.0      1.0     21.0
# product_id                         NaN      NaN      NaN
# seller_id                          NaN      NaN      NaN
# shipping_limit_date                NaN      NaN      NaN
# price                            74.99    134.9   6735.0
# freight_value                    16.26    21.15   409.68
# seller_zip_code_prefix         13568.0  27930.0  99730.0
# seller_city                        NaN      NaN      NaN
# seller_state                       NaN      NaN      NaN
# product_category_name              NaN      NaN      NaN
# product_name_lenght               52.0     57.0     76.0
# product_description_lenght       603.0    987.0   3992.0
# product_photos_qty                 1.0      3.0     20.0
# product_weight_g                 700.0   1800.0  40425.0
# product_length_cm                 25.0     38.0    105.0
# product_height_cm                 13.0     20.0    105.0
# product_width_cm                  20.0     30.0    118.0
# product_category_name_english      NaN      NaN      NaN

# %% [markdown]
# Data pada kolom price memiliki nilai minimum 0.85 dan nilai maksimum 6735.0.
# freight_value memiliki nilai minimum 0 dan nilai maksimum 409.68.
# Penulisan product_category_name_english masih menggunakan huruf kecil dan separator underscore (_).

# %%
#info geolocation.csv
print('\n', geo_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB
#
#  None

# %%
print('\nInfo data null geolocation:\n', geo_df.isnull().sum())
# Out:
# Info data null geolocation:
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print('Info data duplikat geolocation:', geo_df.duplicated().sum())
# Out:
# Info data duplikat geolocation: 261831

# %%
print('\nData describe geolocation:\n', geo_df.describe(include='all'))
# Out:
# Data describe geolocation:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# unique             8011                27
# top           sao paulo                SP
# freq             135800            404268
# mean                NaN               NaN
# std                 NaN               NaN
# min                 NaN               NaN
# 25%                 NaN               NaN
# 50%                 NaN               NaN
# 75%                 NaN               NaN
# max                 NaN               NaN

# %%
geo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# ## Cleaning Data

# %%
#Memberikan huruf kapital pada awal huruf setiap kata di kolom customer_city
city_name = []
for i in range(0, len(joined_df1["customer_city"])):
  k = " ".join([s.capitalize() if s.lower() not in "da|de|do|das|dos" else s for s in joined_df1["customer_city"][i].split()])
  city_name.append(k)

joined_df1["customer_city"] = pd.DataFrame(city_name)

# %%
#Memberikan huruf kapital pada awal huruf setiap kata di kolom seller_city
seller_city_name = []
for i in range(0, len(joined_df2["seller_city"])):
  k = " ".join([s.capitalize() if s.lower() not in "da|de|do|das|dos" else s for s in joined_df2["seller_city"][i].split()])
  seller_city_name.append(k)

joined_df2["seller_city"] = pd.DataFrame(seller_city_name)

# %%
#Memberikan kepanjangan nama dari kolom customer_state dan seller_state (diambil dari situs https://www.drupal.org/node/2559551)
state_name = {
"AC" : "Acre",
"AL" : "Alagoas",
"AM" : "Amazonas",
"AP" : "Amapa",
"BA" : "Bahia",
"CE" : "Ceara",
"DF" : "Distrito Federal",
"ES" : "Espirito Santo",
"GO" : "Goias",
"MA" : "Maranhao",
"MG" : "Minas Gerais",
"MS" : "Mato Grosso do Sul",
"MT" : "Mato Grosso",
"PA" : "Para",
"PB" : "Paraiba",
"PE" : "Pernambuco",
"PI" : "Piaui",
"PR" : "Parana",
"RJ" : "Rio de Janeiro",
"RN" : "Rio Grande do Norte",
"RO" : "Rondonia",
"RR" : "Roraima",
"RS" : "Rio Grande do Sul",
"SC" : "Santa Catarina",
"SE" : "Sergipe",
"SP" : "Sao Paulo",
"TO" : "Tocantins"
}

joined_df1['customer_state'] = joined_df1['customer_state'].map(state_name)
joined_df2['seller_state'] = joined_df2['seller_state'].map(state_name)
joined_df1[['customer_city','customer_state']]
# Out:
#                  customer_city       customer_state
# 0                    Sao Paulo            Sao Paulo
# 1                    Barreiras                Bahia
# 2                   Vianopolis                Goias
# 3      Sao Goncalo do Amarante  Rio Grande do Norte
# 4                  Santo Andre            Sao Paulo
# ...                        ...                  ...
# 99436      Sao Jose dos Campos            Sao Paulo
# 99437             Praia Grande            Sao Paulo
# 99438              Nova Vicosa                Bahia
# 99439                  Japuiba       Rio de Janeiro
# 99440                     Lapa               Parana
#
# [99441 rows x 2 columns]

# %%
joined_df2[['seller_city','seller_state']]
# Out:
#           seller_city    seller_state
# 0       Volta Redonda       Sao Paulo
# 1           Sao Paulo       Sao Paulo
# 2       Borda da Mata    Minas Gerais
# 3              Franca       Sao Paulo
# 4              Loanda          Parana
# ...               ...             ...
# 112645         Itajai  Santa Catarina
# 112646      Sao Paulo       Sao Paulo
# 112647       Curitiba          Parana
# 112648      Sao Paulo       Sao Paulo
# 112649       Ibitinga       Sao Paulo
#
# [112650 rows x 2 columns]

# %% [markdown]
# Data pada kolom 'customer_city' dan 'customer_state' di tabel 'joined_df1', serta 'seller_city' dan 'seller_state' pada joined_df2 telah sesuai dengan kaidah penulisan.

# %%
# Mengganti nama kolom tanggal yang dibutuhkan nanti agar penulisannya lebih pendek
joined_df1 = joined_df1.rename(columns={"order_purchase_timestamp": "order_date",
                                        "order_approved_at": "approved_date",
                                        "order_delivered_carrier_date": "shipped_date",
                                        "order_delivered_customer_date": "delivery_date"}
                               )

# %%
# Menghapus kolom yang tidak dibutuhkan yaitu kolom 'customer_zip_code_prefix'
joined_df1 = joined_df1.drop(columns= ['customer_zip_code_prefix','order_estimated_delivery_date'], axis=1)

# %%
# Mengubah tipe data yang semula objects menjadi datetime dengan for
dt_columns = ['order_date', 'approved_date', 'shipped_date', 'delivery_date']

for column in dt_columns:
  joined_df1[column] = pd.to_datetime(joined_df1[column])

joined_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            99441 non-null  object
#  1   customer_id         99441 non-null  object
#  2   order_status        99441 non-null  object
#  3   order_date          99441 non-null  datetime64[ns]
#  4   approved_date       99281 non-null  datetime64[ns]
#  5   shipped_date        97658 non-null  datetime64[ns]
#  6   delivery_date       96476 non-null  datetime64[ns]
#  7   customer_unique_id  99441 non-null  object
#  8   customer_city       99441 non-null  object
#  9   customer_state      99441 non-null  object
# dtypes: datetime64[ns](4), object(6)
# memory usage: 7.6+ MB

# %%
print("Jumlah NaN pada kolom 'product_category_name_english':", joined_df2.product_category_name_english.isnull().sum())
print("Jumlah NaN pada kolom 'product_category_name_english', tapi tidak NaN pada kolom 'product_category_name':",
      joined_df2.product_category_name_english.loc[joined_df2.product_category_name_english.isna() &
                                                   joined_df2.product_category_name.notnull()].isnull().sum())
# Out:
# Jumlah NaN pada kolom 'product_category_name_english': 1627
# Jumlah NaN pada kolom 'product_category_name_english', tapi tidak NaN pada kolom 'product_category_name': 24

# %%
#Melihat nilai unik pada kolom 'product_category_name' yang tidak memiliki nilai pada kolom 'product_category_name_english'
joined_df2.product_category_name.loc[joined_df2.product_category_name_english.isna() & joined_df2.product_category_name.notnull()].unique()
# Out:
# array(['portateis_cozinha_e_preparadores_de_alimentos', 'pc_gamer'],
#       dtype=object)

# %%
joined_df2[['product_category_name','product_category_name_english']].loc[joined_df2.product_category_name.isna()].reset_index()
# Out:
#        index product_category_name product_category_name_english
# 0        123                   NaN                           NaN
# 1        125                   NaN                           NaN
# 2        132                   NaN                           NaN
# 3        142                   NaN                           NaN
# 4        171                   NaN                           NaN
# ...      ...                   ...                           ...
# 1598  112306                   NaN                           NaN
# 1599  112333                   NaN                           NaN
# 1600  112350                   NaN                           NaN
# 1601  112438                   NaN                           NaN
# 1602  112501                   NaN                           NaN
#
# [1603 rows x 3 columns]

# %%
# Melakukan looping pada list index hasil slicing dan mengisi missing value dengan kondisi dari kolom product_category_name
# tujuannya untuk memberikan nilai yang konsisten pada kolom 'product_category_name_english' berdasarkan nilai pada kolom 'product_category_name'

for i in list(joined_df2.loc[joined_df2.product_category_name_english.isna()].index):
  if joined_df2['product_category_name'].iloc[i] == 'pc_gamer':
    joined_df2['product_category_name_english'].iloc[i] = 'pc_gaming'
  elif joined_df2['product_category_name'].iloc[i] == 'portateis_cozinha_e_preparadores_de_alimentos':
    joined_df2['product_category_name_english'].iloc[i] = 'portable_kitchen_and_food_preparers'
  else:
    joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# Out:
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'portable_kitchen_and_food_preparers'
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# ...
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\2644893907.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_df2['product_category_name_english'].iloc[i] = 'other_products' #yang masih missing value dalam kolom ini diberi nama other_products

# %%
# membuat kolom baru yang berisi nama kategori produk dengan format yang lebih mudah dibaca dan dimengerti 
category_name = []
for i in range(0, len(joined_df2["product_category_name_english"])):
  a = " ".join([s.capitalize() if s.lower() != "and" else s for s in joined_df2["product_category_name_english"][i].split("_")])
  category_name.append(a)

joined_df2["product_category"] = pd.DataFrame(category_name)
joined_df2[["product_category_name_english","product_category"]].head()
# Out:
#   product_category_name_english product_category
# 0                    cool_stuff       Cool Stuff
# 1                      pet_shop         Pet Shop
# 2               furniture_decor  Furniture Decor
# 3                     perfumery        Perfumery
# 4                  garden_tools     Garden Tools

# %%
# Cek jumlah missing value
joined_df2.isna().sum()
# Out:
# order_id                            0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# seller_zip_code_prefix              0
# seller_city                         0
# seller_state                        0
# product_category_name            1603
# product_name_lenght              1603
# product_description_lenght       1603
# product_photos_qty               1603
# product_weight_g                   18
# product_length_cm                  18
# product_height_cm                  18
# product_width_cm                   18
# product_category_name_english       0
# product_category                    0
# dtype: int64

# %%
# Menghapus kolom yang tidak dibutuhkan dan mengecek kembali jumlah missing value
joined_df2 = joined_df2.drop(joined_df2.columns[[4,7]] ,axis=1).drop(joined_df2.iloc[:, 10:19] ,axis=1)
joined_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          112650 non-null  object
#  1   order_item_id     112650 non-null  int64
#  2   product_id        112650 non-null  object
#  3   seller_id         112650 non-null  object
#  4   price             112650 non-null  float64
#  5   freight_value     112650 non-null  float64
#  6   seller_city       112650 non-null  object
#  7   seller_state      112650 non-null  object
#  8   product_category  112650 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 7.7+ MB

# %% [markdown]
# Data tabel joined_df2 telah tidak ada missing value

# %%
# Menggabungkan seluruh tabel ke dalam all_joined_df untuk memudahkan proses visualisasi

all_joined_df = pd.merge(
    left=joined_df1,
    right=joined_df2,
    how="right",
    left_on="order_id",
    right_on="order_id"
)
print('Jumlah baris dan kolom all_joined_df:', all_joined_df.shape)
all_joined_df.head()
# Out:
# Jumlah baris dan kolom all_joined_df: (112650, 18)
#                            order_id                       customer_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1  00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2  000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3  00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
#
#   order_status          order_date       approved_date        shipped_date  \
# 0    delivered 2017-09-13 08:59:02 2017-09-13 09:45:35 2017-09-19 18:34:16
# 1    delivered 2017-04-26 10:53:06 2017-04-26 11:05:13 2017-05-04 14:35:00
# 2    delivered 2018-01-14 14:33:31 2018-01-14 14:48:30 2018-01-16 12:36:48
# 3    delivered 2018-08-08 10:00:35 2018-08-08 10:10:18 2018-08-10 13:28:00
# 4    delivered 2017-02-04 13:57:51 2017-02-04 14:10:13 2017-02-16 09:46:09
#
#         delivery_date                customer_unique_id  \
# 0 2017-09-20 23:43:48  871766c5855e863f6eccc05f988b23cb
# 1 2017-05-12 16:04:24  eb28e67c4c0b83846050ddfb8a35d051
# 2 2018-01-22 13:19:16  3818d81c6709e39d06b2738a8d3a2474
# 3 2018-08-14 13:32:39  af861d436cfc08b2c2ddefd0ba074622
# 4 2017-03-01 16:42:31  64b576fb70d441e8f1b2d7d446e483c5
#
#            customer_city  customer_state  order_item_id  \
# 0  Campos dos Goytacazes  Rio de Janeiro              1
# 1        Santa Fe do Sul       Sao Paulo              1
# 2          Para de Minas    Minas Gerais              1
# 3                Atibaia       Sao Paulo              1
# 4        Varzea Paulista       Sao Paulo              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    freight_value    seller_city  seller_state product_category
# 0          13.29  Volta Redonda     Sao Paulo       Cool Stuff
# 1          19.93      Sao Paulo     Sao Paulo         Pet Shop
# 2          17.87  Borda da Mata  Minas Gerais  Furniture Decor
# 3          12.79         Franca     Sao Paulo        Perfumery
# 4          18.14         Loanda        Parana     Garden Tools

# %%
# Menambah kolom baru bernama total_order_value hasil penjumlahan kolom price dan freight_value
all_joined_df.insert(15, "total_order_value", all_joined_df.price + all_joined_df.freight_value)

# %%
# Mellihat info kolom tabel all_joined_df dan cek missing value
all_joined_df.info()
print('\nJumlah missing value all_joined_df:\n', all_joined_df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   order_id            112650 non-null  object
#  1   customer_id         112650 non-null  object
#  2   order_status        112650 non-null  object
#  3   order_date          112650 non-null  datetime64[ns]
#  4   approved_date       112635 non-null  datetime64[ns]
#  5   shipped_date        111456 non-null  datetime64[ns]
#  6   delivery_date       110196 non-null  datetime64[ns]
#  7   customer_unique_id  112650 non-null  object
#  8   customer_city       112650 non-null  object
#  9   customer_state      112650 non-null  object
#  10  order_item_id       112650 non-null  int64
#  11  product_id          112650 non-null  object
#  12  seller_id           112650 non-null  object
#  13  price               112650 non-null  float64
#  14  freight_value       112650 non-null  float64
#  15  total_order_value   112650 non-null  float64
#  16  seller_city         112650 non-null  object
#  17  seller_state        112650 non-null  object
#  18  product_category    112650 non-null  object
# dtypes: datetime64[ns](4), float64(3), int64(1), object(11)
# memory usage: 16.3+ MB
#
# Jumlah missing value all_joined_df:
#  order_id                 0
# customer_id              0
# order_status             0
# order_date               0
# approved_date           15
# shipped_date          1194
# delivery_date         2454
# customer_unique_id       0
# customer_city            0
# customer_state           0
# order_item_id            0
# product_id               0
# seller_id                0
# price                    0
# freight_value            0
# total_order_value        0
# seller_city              0
# seller_state             0
# product_category         0
# dtype: int64

# %% [markdown]
# Meskipun terdapat missing value kolom tanggal
# Kolom order_date sudah tidak memiliki missing value (untuk keperluan analisis RFM)

# %%
# Melihat jumlah unik dari order_status
all_joined_df.order_status.value_counts()
# Out:
# order_status
# delivered      110197
# shipped          1185
# canceled          542
# invoiced          359
# processing        357
# unavailable         7
# approved            3
# Name: count, dtype: int64

# %% [markdown]
# Status order yang akan dianalisis hanya merupakan order yang disetujui sampai produk diterima pelanggan.

# %%
#Menghapus baris dalam all_joined_df yang mengandung nilai 'canceled' dan 'unavailable' pada kolom order_status karena tidak akan dianalisis
all_joined_df = all_joined_df.drop(all_joined_df[all_joined_df['order_status'].isin(['canceled', 'unavailable'])].index)
all_joined_df.sample(10)
# Out:
#                                 order_id                       customer_id  \
# 59104   86ab8c67b078c9f06af6425f03dc508f  ae6ab14831add8aba2de8b13d0ac1daf
# 44038   6417f67a71244b412018b626fcb084ee  7e9eaa6e37766b7066e95f9153958dcd
# 79681   b539f51f7cf6a9c1a871d2bb898cdd27  590e0ece7d320dac89d029c8b3b9f23a
# 95350   d83f19fa5fce346e31c60b35257f4329  4da1bfe6e373952b0ecbeb6b54343fb4
# 4108    0937ee5de4e9482b7503bae26f9d243f  3d4c473f325542281c88efce5ae91375
# 110242  fa7b6165adc28533bf8a87017c00f045  bfa0542e3861940576dff9b4c651555e
# 86245   c3e544a509d5603803d4f6eaedcaf0b8  67ccb8621f5cb3f53b797fe9af6143c6
# 73703   a7f3eb9a2e38d344a3311dbbf4c5d9ba  5bef7bd0989f84e5cb0cafb53e005c0e
# 63840   91ce7ca124af689166db5eeed6f67a58  5123a836ba289609cd3d54332637ca88
# 41133   5db9b0ad19ea0543caa70c934783946c  058f3fdd496fc2cd91c21bf8fe4b1a29
#
#        order_status          order_date       approved_date  \
# 59104     delivered 2017-11-24 00:37:39 2017-11-24 01:10:44
# 44038     delivered 2018-08-10 08:09:28 2018-08-10 08:25:09
# 79681     delivered 2018-08-16 17:56:44 2018-08-16 18:10:29
# 95350     delivered 2018-08-04 20:51:49 2018-08-07 04:24:50
# 4108      delivered 2018-08-23 08:47:54 2018-08-23 09:04:43
# 110242    delivered 2018-04-08 15:54:56 2018-04-08 16:09:59
# 86245     delivered 2017-08-07 18:36:25 2017-08-07 18:50:19
# 73703     delivered 2018-02-12 09:11:31 2018-02-12 09:48:43
# 63840     delivered 2017-11-25 23:11:44 2017-11-25 23:32:59
# 41133     delivered 2018-04-05 22:12:22 2018-04-06 08:55:24
#
#               shipped_date       delivery_date  \
# 59104  2017-11-30 15:59:42 2017-12-07 16:43:28
# 44038  2018-08-10 10:25:00 2018-08-27 13:02:58
# 79681  2018-08-17 14:20:00 2018-08-22 13:34:45
# 95350  2018-08-09 14:14:00 2018-08-13 19:48:30
# 4108   2018-08-23 14:10:00 2018-08-30 00:56:19
# 110242 2018-04-12 18:21:38 2018-04-13 18:09:47
# 86245  2017-08-08 14:28:54 2017-08-11 13:12:42
# 73703  2018-02-14 15:53:04 2018-02-19 15:47:08
# 63840  2017-11-27 22:41:42 2017-12-05 14:55:03
# 41133  2018-04-13 00:44:44 2018-05-07 18:18:45
#
#                       customer_unique_id          customer_city  \
# 59104   b7afc3a32c7c5ccbac116285bb835ac2         Belo Horizonte
# 44038   7ae0d12487db80163fd8a2c7506ac52f                 Iguatu
# 79681   2c2ccd48722aa6843d258a9f16f012a9                Jandira
# 95350   9c330533c835ab41963b6e398914d43f              Sao Paulo
# 4108    cd13689db46ae3b167ccb071ebbc0e86            Teresopolis
# 110242  28432af34e1b2a04d7f5318a3f64a71a  Sao Bernardo do Campo
# 86245   e8d4edef117c8915ae15d8fb4bd24f41              Sao Paulo
# 73703   b11298d6219d5905a7d03447b8fa4be2              Sao Paulo
# 63840   bdde9ce1c27b88a7fe3ef13ad6a80b5f              Sao Paulo
# 41133   80daff16b5c8f4ec8b89fe10a66a3cc1              Fortaleza
#
#         customer_state  order_item_id                        product_id  \
# 59104     Minas Gerais              1  32b2a45c7698faf599ad250c65f6f633
# 44038            Ceara              1  a94567e6e87ea78a1be38458e59847dd
# 79681        Sao Paulo              1  e55ed19897a6692649240b894020d683
# 95350        Sao Paulo              1  e7cc48a9daff5436f63d3aad9426f28b
# 4108    Rio de Janeiro              1  8fb8fc612eb9832ae220a1b88f3b375d
# 110242       Sao Paulo              1  4e5696c21b0c174738e7929b147b7126
# 86245        Sao Paulo              1  d321d5e90b24cba895f0564fc3e15a84
# 73703        Sao Paulo              1  43af87f38a5fdd07c23a32ec33727ba9
# 63840        Sao Paulo              1  aa6a696816c69cb3bffdf42d62642a80
# 41133            Ceara              1  c6c99dd4d0be36139d78cd917a5bdda3
#
#                                seller_id   price  freight_value  \
# 59104   e8b3a3a38279a82f0e5d006d5e5b7d2c   39.90          17.92
# 44038   dbd66278cbfe1aa1000f90a217ca4695   39.90          37.19
# 79681   082e0bf4cb865a6533b1e8e498cc0255   48.00          77.42
# 95350   53243585a1d6dc2643021fd1853d8905  170.00          25.54
# 4108    402916f742e5c740cc751493d9cf5053  149.00          19.14
# 110242  3969863bb8af7f72580b3b1ffd3a17b3   54.49          13.43
# 86245   aafe36600ce604f205b86b5084d3d767   59.90          15.18
# 73703   6a8b085f816a1f75f92dbac6eb545f8f   19.50          11.85
# 63840   897060da8b9a21f655304d50fd935913   34.95          11.85
# 41133   18a349e75d307f4b4cc646a691ed4216   44.95          19.04
#
#         total_order_value       seller_city    seller_state  \
# 59104               57.82           Jussara          Parana
# 44038               77.09         Sao Paulo       Sao Paulo
# 79681              125.42          Botucatu       Sao Paulo
# 95350              195.54  Lauro de Freitas           Bahia
# 4108               168.14          Guanhaes    Minas Gerais
# 110242              67.92         Sao Paulo       Sao Paulo
# 86245               75.08          Sao Jose  Santa Catarina
# 73703               31.35         Bebedouro       Sao Paulo
# 63840               46.80    Ribeirao Preto       Sao Paulo
# 41133               63.99         Sao Paulo       Sao Paulo
#
#                  product_category
# 59104              Consoles Games
# 44038                 Electronics
# 79681                Garden Tools
# 95350                   Telephony
# 4108                Health Beauty
# 110242      Furniture Living Room
# 86245                        Baby
# 73703                        Auto
# 63840       Computers Accessories
# 41133   Construction Tools Safety

# %%
# Melihat jumlah unik dari order_status
all_joined_df.order_status.value_counts()
# Out:
# order_status
# delivered     110197
# shipped         1185
# invoiced         359
# processing       357
# approved           3
# Name: count, dtype: int64

# %%
# Cek jumlah missing value all_joined_df setelah drop baris dengan order_status canceled dan unavailable
all_joined_df.isna().sum()
# Out:
# order_id                 0
# customer_id              0
# order_status             0
# order_date               0
# approved_date           15
# shipped_date           721
# delivery_date         1912
# customer_unique_id       0
# customer_city            0
# customer_state           0
# order_item_id            0
# product_id               0
# seller_id                0
# price                    0
# freight_value            0
# total_order_value        0
# seller_city              0
# seller_state             0
# product_category         0
# dtype: int64

# %%
#Membuat kolom baru dengan menggunakan kolom order_date dari all_joined_df
all_joined_df.insert(3,'hour_order', all_joined_df['order_date'].apply(lambda x: x.hour)) 

hours_bins = [-0.1, 6, 12, 18, 23]
hours_labels = ['Dawn', 'Morning', 'Afternoon', 'Night']
all_joined_df.insert(4,'daytime_order', (pd.cut(all_joined_df['hour_order'], hours_bins, labels=hours_labels))) 

all_joined_df.insert(5,'day_order', all_joined_df['order_date'].dt.strftime('%A'))
all_joined_df.insert(6,'date_order', all_joined_df['order_date'].dt.strftime('%d')) 
all_joined_df.insert(7,'month_order', all_joined_df['order_date'].dt.strftime('%m-%Y'))

all_joined_df.sample(15)
# Out:
#                                 order_id                       customer_id  \
# 112168  fed8a749f5633fa9f58ed475eb2c5cef  3d58bf9be1514f3002aeefccf9746d26
# 108120  f5b364f870f2417bb837200eac7677d6  76190209cd924a1054418c59c03c16c8
# 90992   cea7e28bd63ef382ebf6010b228208f2  8463f85157c2e1a8f03042947b10101f
# 109662  f939f0226d610aad8bc41cb7433e5f70  4898298d72e64f88fc72c75881bb26d6
# 103563  eb331761cad75951ae1b5c9dd275cd22  596476030ef36305e6dc6d82812d9ea0
# 47264   6b67ec6cfd19c0a30f91afb6bd431e8f  c2b0ea6dfda294a608886e885972199a
# 96232   da5a0865ec4bbc8e19541e9e51b1c523  cdc937e42ae5b5bc61c4e17d691b280f
# 24964   38d28e168501494c0edb4ee41f64d296  6620ea0cda2c99d5c14c22c7c6309979
# 73787   a82a8de42e1aa1d5c74f83f7b23fbea9  b6dac2712e2f2441f14582d81cf07a4f
# 16988   26e5ea27a6fddbbf4b360bdcd90c30c8  a9393533a76acd87a5bd1768ef52cf7f
# 37495   551c21a415e6d07ce3dfc85e627f8aaf  6e34e7ad19aa3c59753c0ac91ccb34d9
# 102874  e9a04e230494b2b61ebb85529c4f9269  f0d3477ffb762f6ca6c099d34ca9589b
# 99725   e2221180a668e1cc096f9e9e3572868f  8c382656b44e6d6375d2fea25375fb02
# 44552   6540a36b3dd6a4a0922d5f57d493d9d6  4a5ad00d2abdca6e32331bfa18f35b4d
# 59712   880ef31ce18ff13a46bdd8d07e2ed86a  a18e4a6af6ed2d86ea103da9e4ca0c6e
#
#        order_status  hour_order daytime_order  day_order date_order  \
# 112168    delivered          19         Night     Monday         04
# 108120    delivered          12       Morning  Wednesday         12
# 90992     delivered          13     Afternoon    Tuesday         24
# 109662    delivered           1          Dawn     Sunday         19
# 103563    delivered          19         Night     Friday         19
# 47264     delivered          10       Morning    Tuesday         20
# 96232     delivered          11       Morning   Thursday         29
# 24964     delivered          17     Afternoon   Saturday         02
# 73787     delivered          17     Afternoon    Tuesday         10
# 16988     delivered          10       Morning    Tuesday         24
# 37495     delivered          14     Afternoon     Monday         22
# 102874    delivered          10       Morning     Monday         26
# 99725     delivered          12       Morning   Thursday         01
# 44552     delivered          18     Afternoon     Friday         19
# 59712     delivered          12       Morning     Monday         13
#
#        month_order          order_date       approved_date  ...  \
# 112168     12-2017 2017-12-04 19:13:48 2017-12-04 19:30:16  ...
# 108120     04-2017 2017-04-12 12:53:23 2017-04-13 02:42:25  ...
# 90992      04-2018 2018-04-24 13:39:20 2018-04-24 17:43:21  ...
# 109662     11-2017 2017-11-19 01:23:23 2017-11-19 03:07:58  ...
# 103563     01-2018 2018-01-19 19:23:27 2018-01-19 19:37:14  ...
# 47264      02-2018 2018-02-20 10:45:27 2018-02-20 10:55:35  ...
# 96232      06-2017 2017-06-29 11:52:53 2017-06-30 13:30:23  ...
# 24964      06-2018 2018-06-02 17:29:04 2018-06-02 17:50:18  ...
# 73787      04-2018 2018-04-10 17:04:00 2018-04-10 17:16:19  ...
# 16988      10-2017 2017-10-24 10:43:48 2017-10-24 10:56:14  ...
# 37495      01-2018 2018-01-22 14:51:03 2018-01-22 15:12:50  ...
# 102874     02-2018 2018-02-26 10:09:01 2018-02-26 11:01:16  ...
# 99725      03-2018 2018-03-01 12:52:29 2018-03-01 13:09:46  ...
# 44552      01-2018 2018-01-19 18:52:30 2018-01-23 03:39:20  ...
# 59712      08-2018 2018-08-13 12:28:29 2018-08-13 12:45:11  ...
#
#         customer_state order_item_id                        product_id  \
# 112168       Sao Paulo             1  09d0b4ab2eaebcde59d4dd8bea2c6be6
# 108120       Sao Paulo             1  6e1b14d3cbb5fb3a2c00351007127dfd
# 90992        Sao Paulo             1  2948658cb6abc82847412be7201bfc4c
# 109662  Rio de Janeiro             1  81f869ddb8b8e77514002be908adbacc
# 103563       Sao Paulo             1  bc74f63361c15c1a5baa5b97ac432e62
# 47264     Minas Gerais             1  37e7030d6095e672ebf05e2133b1a1bf
# 96232           Parana             1  eafe7084b1d20c58faacfe86983c73ad
# 24964   Rio de Janeiro             1  7ff723bcd6aafa0ba68c45f550e7dc0b
# 73787           Parana             1  6c3fc3c928cf7d57418923ffea326d9a
# 16988   Santa Catarina             1  95fcb44ada4cefca4f03cc0b4b69ee33
# 37495        Sao Paulo             1  7935ddc510afb7d08989660b382b7f26
# 102874       Sao Paulo             1  629e019a6f298a83aeecc7877964f935
# 99725        Sao Paulo             1  92503fc18ca14a8f32c182ce3f1b9f05
# 44552   Rio de Janeiro             1  ac521e68c0341f41844e953ca1659a9e
# 59712        Sao Paulo             1  8b18b26ce90f9f0e4c9ae339e532f325
#
#                                seller_id   price  freight_value  \
# 112168  f3da5b2ff499efb8d4a6d371d175d7dd   81.20          11.77
# 108120  7a67c85e85bb2ce8582c35f2203ad736  219.99          15.31
# 90992   955fee9216a65b617aa5c0531780ce60  110.00          18.85
# 109662  7142540dd4c91e2237acb7e911c4eba2   89.90          17.88
# 103563  4869f7a5dfa277a7dca6462dcf3b52b2  199.00          12.89
# 47264   3d4b1ae7539303b5704493798893e82c  107.00          14.50
# 96232   066a6914e1ebf3ea95a216c73a986b91  439.00          25.87
# 24964   7a67c85e85bb2ce8582c35f2203ad736   69.99          23.07
# 73787   7a67c85e85bb2ce8582c35f2203ad736   51.99          16.33
# 16988   2e1c9f22be269ef4643f826c9e650a52  144.49          18.26
# 37495   3d871de0142ce09b7081e2b9d1733cb1   79.00          13.57
# 102874  c003204e1ab016dfa150abc119207b24  119.90          14.44
# 99725   3586b8580d9c917874e053a1bb37b5ff   29.90          17.06
# 44552   855668e0971d4dfd7bef1b6a4133b41b   25.00          15.10
# 59712   c3cfdc648177fdbbbb35635a37472c53  179.90          22.56
#
#        total_order_value           seller_city  seller_state  \
# 112168             92.97             Sao Paulo     Sao Paulo
# 108120            235.30             Sao Paulo     Sao Paulo
# 90992             128.85             Sao Paulo     Sao Paulo
# 109662            107.78             Penapolis     Sao Paulo
# 103563            211.89               Guariba     Sao Paulo
# 47264             121.50             Sao Paulo     Sao Paulo
# 96232             464.87         Foz do Iguacu        Parana
# 24964              93.06             Sao Paulo     Sao Paulo
# 73787              68.32             Sao Paulo     Sao Paulo
# 16988             162.75             Sao Paulo     Sao Paulo
# 37495              92.57  Campo Limpo Paulista     Sao Paulo
# 102874            134.34               Cajamar     Sao Paulo
# 99725              46.96            Araraquara     Sao Paulo
# 44552              40.10               Itatiba     Sao Paulo
# 59712             202.46              Curitiba        Parana
#
#            product_category
# 112168                 Toys
# 108120           Cool Stuff
# 90992         Health Beauty
# 109662                 Auto
# 103563        Health Beauty
# 47264   Musical Instruments
# 96232        Sports Leisure
# 24964                  Baby
# 73787            Cool Stuff
# 16988         Health Beauty
# 37495            Stationery
# 102874                 Auto
# 99725            Stationery
# 44552                  Baby
# 59712        Sports Leisure
#
# [15 rows x 24 columns]

# %% [markdown]
# Data dari all_joined df siap digunakan untuk dieksplorasi dan dianalisis

# %% [markdown]
# # EDA

# %% [markdown]
# ## Spesifikasi Pelanggan

# %%
# banyaknya jumlah pelanggan di tiap kota berdasarkan customer_city
customers_in_cities = all_joined_df.groupby(by="customer_city").customer_unique_id.nunique().sort_values(ascending=False).reset_index()
customers_in_cities = customers_in_cities.rename(columns={'customer_unique_id':'count_customers'}).head(15)
customers_in_cities
# Out:
#             customer_city  count_customers
# 0               Sao Paulo            14761
# 1          Rio de Janeiro             6545
# 2          Belo Horizonte             2641
# 3                Brasilia             2051
# 4                Curitiba             1447
# 5                Campinas             1379
# 6            Porto Alegre             1317
# 7                Salvador             1199
# 8               Guarulhos             1133
# 9   Sao Bernardo do Campo              891
# 10                Niteroi              804
# 11            Santo Andre              760
# 12                 Osasco              709
# 13                 Santos              686
# 14                Goiania              661

# %% [markdown]
# Pelanggan yang bertransaksi paling banyak berada pada kota Sao Paulo sebanyak 14.761 orang

# %%
# jumlah pelanggan berdasarkan customer_state
customers_in_states = all_joined_df.groupby(by="customer_state").customer_unique_id.nunique().sort_values(ascending=False).reset_index()
customers_in_states = customers_in_states.rename(columns={'customer_unique_id':'count_customers'}).head(15)
customers_in_states.head()
# Out:
#       customer_state  count_customers
# 0          Sao Paulo            39747
# 1     Rio de Janeiro            12241
# 2       Minas Gerais            11134
# 3  Rio Grande do Sul             5233
# 4             Parana             4824

# %% [markdown]
# Jumlah pelanggan terbanyak berada pada negara bagian Sao Paulo sebanyak 39.747 orang

# %%
# pelanggan yang memiliki nilai total order terbanyak
sum_order = all_joined_df.groupby(by="customer_unique_id").agg(count_order = ('order_id','nunique'), sum_order_value = ('total_order_value', 'sum')).reset_index()
sum_order_sorted = sum_order.sort_values(by='sum_order_value', ascending=False).head(15)
sum_order_sorted
# Out:
#                      customer_unique_id  count_order  sum_order_value
# 3788   0a0a92112bd4c708ca5fde585afaa872            1         13664.08
# 81011  da122df9eeddfedc1dc1f5349a1a690c            2          7571.63
# 43938  763c8b1c9c68a0229c42c9fc6f662b93            1          7274.88
# 81850  dc4802a71eae9be1dd28f5d788ceb526            1          6929.31
# 25901  459bef486812aa25204be022145caa62            1          6922.21
# 94696  ff4159b92c40ebe40454e3e6a7c35ed6            1          6726.66
# 23841  4007669dec559734d6f53e029e360987            1          6081.54
# 88651  eebb5dda148d3893cdaf5b5ca3040ccb            1          4764.34
# 27124  48e1ac109decbb87765a3eade6854098            1          4681.78
# 74401  c8460e4251689ba205045f3ea17884a1            4          4655.88
# 88353  edde2314c6c30e864a128ac95d6b2112            1          4513.32
# 60210  a229eba70ec1c2abef51f04987deb7a5            1          4445.50
# 88388  edf81e1f3070b9dac83ec83dacdbb9bc            1          4194.76
# 92914  fa562ef24d41361e476e748681810e1e            1          4175.26
# 75108  ca27f3dac28fb1063faddd424c9d95fa            1          4163.51

# %% [markdown]
# Pelanggan dengan ID '0a0a92112bd4c708ca5fde585afaa872' memiliki nilai total order tertinggi yaitu sebesar R$13.664.08, dengan hanya sekali order.

# %%
# pelanggan yang paling sering melakukan order
count_order = all_joined_df.groupby(by="customer_unique_id").agg(count_order = ('order_id','nunique'), sum_order_value = ('total_order_value', 'sum')).reset_index()
count_order_sorted = count_order.sort_values(by=['count_order','sum_order_value'], ascending=False).head(15)
count_order_sorted
# Out:
#                      customer_unique_id  count_order  sum_order_value
# 52352  8d50f5eadf50201ccdcedfb9e2ac8455           16           902.04
# 23198  3e43e6105506432c953e165fb2acf44c            9          1172.67
# 75205  ca77025e7201e3b30c44b472ff346268            7          1122.72
# 10234  1b6c7548a2a1f9037c1fd3ddfed95f33            7           959.01
# 37370  6469f99c1f9dfae7733b25662e7f1782            7           758.83
# 81925  dc813062e0fc23409cd255f7f53c7074            6          1033.62
# 26733  47c1a3033b8b77b3ab6e109eb4d5fdf3            6           944.21
# 37161  63cfc61cee11cbe306bff5857d00bfe4            6           826.32
# 89402  f0e310a6839dce9de1638e0fe5ab282a            6           540.69
# 7091   12f5d6e1cbf93dafd9dcc19095df0b3d            6           110.72
# 94428  fe81bb32c243a86b2f86fbf053fe6140            5          1590.76
# 35222  5e8f38a9a1c023f3db718edcf926a2db            5          1114.18
# 32290  56c8638e7c058b98aae6d74d2dd6ea23            5           806.47
# 21336  394ac4de8f3acb14253c177f0e15bc58            5           745.41
# 20112  35ecdf6858edc6427223b64804cf028e            5           603.90

# %% [markdown]
# Pelanggan dengan ID '8d50f5eadf50201ccdcedfb9e2ac8455' paling sering melakukan order hingga 16 kali, dengan nilai total order nya sebesar R$902,94.

# %% [markdown]
# ## Spesifikasi Penjual

# %%
# jumlah penjual tiap kota berdasarkan seller_city
sellers_in_cities = all_joined_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).reset_index()
sellers_in_cities = sellers_in_cities.rename(columns={'seller_id':'count_sellers'}).head(15)
sellers_in_cities
# Out:
#               seller_city  count_sellers
# 0               Sao Paulo            683
# 1                Curitiba            126
# 2          Rio de Janeiro             96
# 3          Belo Horizonte             65
# 4          Ribeirao Preto             52
# 5               Guarulhos             50
# 6                Ibitinga             49
# 7             Santo Andre             45
# 8                Campinas             40
# 9                 Maringa             40
# 10               Sorocaba             32
# 11  Sao Jose do Rio Preto             31
# 12  Sao Bernardo do Campo             31
# 13                 Osasco             30
# 14           Porto Alegre             28

# %% [markdown]
# Jumlah penjual terbanyak berasal dari kota Sao Paulo sebanyak 683 penjual

# %%
# jumlah penjual berdasarkan seller_state
sellers_in_states = all_joined_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).reset_index()
sellers_in_states = sellers_in_states.rename(columns={'seller_id':'count_sellers'}).head(15)
sellers_in_states
# Out:
#            seller_state  count_sellers
# 0             Sao Paulo           1822
# 1                Parana            344
# 2          Minas Gerais            240
# 3        Santa Catarina            186
# 4        Rio de Janeiro            170
# 5     Rio Grande do Sul            129
# 6                 Goias             40
# 7      Distrito Federal             30
# 8        Espirito Santo             23
# 9                 Bahia             19
# 10                Ceara             12
# 11           Pernambuco              9
# 12              Paraiba              6
# 13  Rio Grande do Norte              5
# 14   Mato Grosso do Sul              5

# %% [markdown]
# Jumlah penjual terbanyak berasal dari negara bagian Sao Paulo sebanyak 1.822 penjual

# %%
# penjual yang memiliki nilai total order terbesar
seller_sum_order = all_joined_df.groupby(by="seller_id").agg(count_order = ('order_id','nunique'), sum_order_value = ('total_order_value', 'sum')).reset_index()
seller_sum_order_sorted = seller_sum_order.sort_values(by='sum_order_value', ascending=False).head(15)
seller_sum_order_sorted
# Out:
#                              seller_id  count_order  sum_order_value
# 849   4869f7a5dfa277a7dca6462dcf3b52b2         1131        249393.44
# 1515  7c67e1448b00f6e969d365cea6b010ab          982        239536.44
# 1000  53243585a1d6dc2643021fd1853d8905          358        235856.68
# 873   4a3ca9315b744ce9f8e9374361493884         1804        235359.30
# 2984  fa1c13f2614d7b5c4749cbc52fecda94          584        202861.67
# 2611  da8622b14eb17ae2831f4ac5b9dab84a         1314        185192.32
# 1540  7e93a43ef30c4f03f38b393420bc753a          332        178838.42
# 191   1025f0e2d44d7041d6cf58b6550e0bfa          915        172860.69
# 1485  7a67c85e85bb2ce8582c35f2203ad736         1159        162607.24
# 1799  955fee9216a65b617aa5c0531780ce60         1286        160582.90
# 1219  6560211a19b47992c3666cc44a7e94c0         1847        150522.02
# 366   1f50f920176fa81dab994f9023523100         1403        142037.48
# 835   46dc3b2cc0980fb8ec44634e21d2718e          518        138919.78
# 1929  a1043bafd471dff536d0c462352beb48          715        133195.80
# 2451  cc419e0650a3c5ba77189a1882b7556a         1697        129169.95

# %%
# penjual yang mendapatkan order terbanyak
seller_count_order = all_joined_df.groupby(by="seller_id").agg(count_order = ('order_id','nunique'), sum_order_value = ('total_order_value', 'sum')).reset_index()
seller_count_order_sorted = seller_count_order.sort_values(by=['count_order','sum_order_value'], ascending=False).head(15)
seller_count_order_sorted
# Out:
#                              seller_id  count_order  sum_order_value
# 1219  6560211a19b47992c3666cc44a7e94c0         1847        150522.02
# 873   4a3ca9315b744ce9f8e9374361493884         1804        235359.30
# 2451  cc419e0650a3c5ba77189a1882b7556a         1697        129169.95
# 366   1f50f920176fa81dab994f9023523100         1403        142037.48
# 2611  da8622b14eb17ae2831f4ac5b9dab84a         1314        185192.32
# 1799  955fee9216a65b617aa5c0531780ce60         1286        160582.90
# 1485  7a67c85e85bb2ce8582c35f2203ad736         1159        162607.24
# 2800  ea8482cd71df3c1969d7b9473ff13abc         1145         54684.52
# 849   4869f7a5dfa277a7dca6462dcf3b52b2         1131        249393.44
# 724   3d871de0142ce09b7081e2b9d1733cb1         1076        116835.80
# 1515  7c67e1448b00f6e969d365cea6b010ab          982        239536.44
# 1685  8b321bb669392f5163d04c59e235e066          943         31692.05
# 191   1025f0e2d44d7041d6cf58b6550e0bfa          915        172860.69
# 1182  620c87c171fb2a6dd6e8bb4dec959fc6          732        127674.78
# 1929  a1043bafd471dff536d0c462352beb48          715        133195.80

# %% [markdown]
# ## Order Pelanggan Berdasarkan Kategori Produk

# %%
# kategori produk dengan jumlah order tertinggi/terbanyak
order_by_product_category = all_joined_df.groupby(by="product_category").agg(num_of_order = ('order_id','count'), sum_order_value = ('total_order_value', 'sum')).reset_index()
order_by_product_category.sort_values(by=['num_of_order','sum_order_value'], ascending=False).head(15)
# Out:
#          product_category  num_of_order  sum_order_value
# 7          Bed Bath Table         11097       1240386.13
# 43          Health Beauty          9634       1437665.78
# 68         Sports Leisure          8590       1147244.63
# 39        Furniture Decor          8298        899626.04
# 15  Computers Accessories          7781       1050941.58
# 49             Housewares          6915        772035.14
# 73          Watches Gifts          5970       1298292.47
# 71              Telephony          4527        393306.02
# 42           Garden Tools          4328        579525.20
# 5                    Auto          4204        678606.64
# 72                   Toys          4083        556783.29
# 20             Cool Stuff          3779        704086.24
# 61              Perfumery          3402        450580.47
# 6                    Baby          3043        478320.00
# 26            Electronics          2755        203416.77

# %% [markdown]
# kategori produk yang paling banyak di order adalah 'Bed Bath Table' dengan total jumlah order adalah 11097

# %%
# kategori produk dengan jumlah order terendah
order_by_product_category.sort_values('num_of_order', ascending=True).head(15)
# Out:
#                        product_category  num_of_order  sum_order_value
# 64                Security and Services             2           324.51
# 60                            Pc Gaming             8          1430.10
# 29            Fashion Childrens Clothes             8           665.36
# 52                           La Cuisine            14          2388.54
# 63  Portable Kitchen and Food Preparers            14          4228.05
# 11                    Cds Dvds Musicals            14           954.99
# 3                 Arts and Craftmanship            24          2184.14
# 46                       Home Comfort 2            30          1170.58
# 32                        Fashion Sport            30          2697.64
# 35                              Flowers            33          1598.91
# 55                                Music            38          6724.86
# 41    Furniture Mattress and Upholstery            38          5998.54
# 23                  Diapers and Hygiene            38          2101.25
# 59                       Party Supplies            43          5313.15
# 27               Fashio Female Clothing            48          3425.39

# %% [markdown]
# kategori produk yang paling sedikit di order adalah 'Security and Services' dengan jumlah order hanya sebanyak 2

# %%
# kategori produk dengan total nilai order tertinggi
order_by_product_category.sort_values('sum_order_value', ascending=False).head(15)
# Out:
#          product_category  num_of_order  sum_order_value
# 43          Health Beauty          9634       1437665.78
# 73          Watches Gifts          5970       1298292.47
# 7          Bed Bath Table         11097       1240386.13
# 68         Sports Leisure          8590       1147244.63
# 15  Computers Accessories          7781       1050941.58
# 39        Furniture Decor          8298        899626.04
# 49             Housewares          6915        772035.14
# 20             Cool Stuff          3779        704086.24
# 5                    Auto          4204        678606.64
# 42           Garden Tools          4328        579525.20
# 72                   Toys          4083        556783.29
# 6                    Baby          3043        478320.00
# 61              Perfumery          3402        450580.47
# 71              Telephony          4527        393306.02
# 57       Office Furniture          1690        342073.02

# %% [markdown]
# kategori produk dengan nilai order tertinggi adalah 'Health Beauty' dengan nilai order sebesar 1437665.78

# %%
# kategori produk dengan total nilai order terendah
order_by_product_category.sort_values('sum_order_value', ascending=True).head(15)
# Out:
#                        product_category  num_of_order  sum_order_value
# 64                Security and Services             2           324.51
# 29            Fashion Childrens Clothes             8           665.36
# 11                    Cds Dvds Musicals            14           954.99
# 46                       Home Comfort 2            30          1170.58
# 60                            Pc Gaming             8          1430.10
# 35                              Flowers            33          1598.91
# 23                  Diapers and Hygiene            38          2101.25
# 3                 Arts and Craftmanship            24          2184.14
# 52                           La Cuisine            14          2388.54
# 32                        Fashion Sport            30          2697.64
# 27               Fashio Female Clothing            48          3425.39
# 63  Portable Kitchen and Food Preparers            14          4228.05
# 59                       Party Supplies            43          5313.15
# 9                        Books Imported            60          5409.70
# 25                         Dvds Blu Ray            62          5804.37

# %% [markdown]
# kategori produk dengan nilai order terendah adalah 'Security and Services' dengan nilai order sebesar 324.51

# %% [markdown]
# ## Spesifikasi dan Perkembangan Order Pelanggan

# %%
count_hour_order = all_joined_df.groupby('hour_order').order_id.nunique().reset_index()
count_hour_order = count_hour_order.rename(columns={'order_id':'count_orders'})
count_hour_order
# Out:
#     hour_order  count_orders
# 0            0          2362
# 1            1          1151
# 2            2           503
# 3            3           267
# 4            4           205
# 5            5           185
# 6            6           493
# 7            7          1218
# 8            8          2939
# 9            9          4712
# 10          10          6083
# 11          11          6497
# 12          12          5918
# 13          13          6429
# 14          14          6491
# 15          15          6370
# 16          16          6594
# 17          17          6073
# 18          18          5707
# 19          19          5899
# 20          20          6116
# 21          21          6145
# 22          22          5761
# 23          23          4081

# %%
#Order pelanggan berdasarkan waktu pemesanan
count_daytime_order = all_joined_df.groupby('daytime_order').order_id.nunique().reset_index()
count_daytime_order = count_daytime_order.rename(columns={'order_id':'count_orders'})
count_daytime_order
# Out:
#   daytime_order  count_orders
# 0          Dawn          5166
# 1       Morning         27367
# 2     Afternoon         37664
# 3         Night         28002

# %% [markdown]
# Pemesanan paling banyak dilakukan pada siang hari

# %%
#Order pelanggan berdasarkan hari pemesanan
day_order_df = all_joined_df.groupby('day_order').order_id.nunique().reset_index().sort_values(by='order_id', ascending=False)
day_order_df = day_order_df.rename(columns={'order_id':'count_orders'})
day_order_df
# Out:
#    day_order  count_orders
# 1     Monday         15978
# 5    Tuesday         15758
# 6  Wednesday         15350
# 4   Thursday         14571
# 0     Friday         13948
# 3     Sunday         11831
# 2   Saturday         10763

# %% [markdown]
# Pemesanan paling banyak dilakukan pada hari Senin

# %%
#Order pelanggan berdasarkan waktu dan hari pemesanan
count_time_order = all_joined_df.groupby(['day_order','daytime_order']).order_id.nunique().reset_index()
count_time_order.insert(2, 'time_order', count_time_order[['day_order',	'daytime_order']].agg(', '.join, axis=1))
count_time_order = count_time_order.rename(columns={'order_id':'count_orders'})
count_time_order.sort_values(by='count_orders', ascending=False)
# Out:
#     day_order daytime_order            time_order  count_orders
# 6      Monday     Afternoon     Monday, Afternoon          6124
# 22    Tuesday     Afternoon    Tuesday, Afternoon          6066
# 26  Wednesday     Afternoon  Wednesday, Afternoon          5837
# 18   Thursday     Afternoon   Thursday, Afternoon          5587
# 2      Friday     Afternoon     Friday, Afternoon          5390
# 7      Monday         Night         Monday, Night          4742
# 23    Tuesday         Night        Tuesday, Night          4536
# 25  Wednesday       Morning    Wednesday, Morning          4522
# 14     Sunday     Afternoon     Sunday, Afternoon          4483
# 21    Tuesday       Morning      Tuesday, Morning          4466
# 5      Monday       Morning       Monday, Morning          4448
# 17   Thursday       Morning     Thursday, Morning          4342
# 1      Friday       Morning       Friday, Morning          4223
# 15     Sunday         Night         Sunday, Night          4191
# 10   Saturday     Afternoon   Saturday, Afternoon          4177
# 27  Wednesday         Night      Wednesday, Night          4161
# 19   Thursday         Night       Thursday, Night          3866
# 3      Friday         Night         Friday, Night          3418
# 11   Saturday         Night       Saturday, Night          3088
# 9    Saturday       Morning     Saturday, Morning          2807
# 13     Sunday       Morning       Sunday, Morning          2559
# 0      Friday          Dawn          Friday, Dawn           917
# 24  Wednesday          Dawn       Wednesday, Dawn           830
# 16   Thursday          Dawn        Thursday, Dawn           776
# 8    Saturday          Dawn        Saturday, Dawn           691
# 20    Tuesday          Dawn         Tuesday, Dawn           690
# 4      Monday          Dawn          Monday, Dawn           664
# 12     Sunday          Dawn          Sunday, Dawn           598

# %% [markdown]
# Pemesanan paling banyak dilakukan pada hari Senin-Jumat di siang hari

# %%
count_date_order = all_joined_df.groupby('date_order').order_id.nunique().reset_index()
count_date_order = count_date_order.rename(columns={'order_id':'count_orders'})
count_date_order.sort_values(by='count_orders', ascending=False)
# Out:
#    date_order  count_orders
# 23         24          3835
# 15         16          3546
# 14         15          3485
# 3          04          3449
# 5          06          3408
# 17         18          3405
# 4          05          3388
# 13         14          3345
# 18         19          3340
# 6          07          3313
# 7          08          3284
# 10         11          3270
# 24         25          3259
# 25         26          3254
# 2          03          3239
# 12         13          3228
# 8          09          3221
# 19         20          3217
# 1          02          3171
# 16         17          3158
# 11         12          3153
# 21         22          3145
# 9          10          3124
# 26         27          3091
# 22         23          3089
# 20         21          3074
# 0          01          3066
# 27         28          2982
# 28         29          2517
# 29         30          2492
# 30         31          1651

# %% [markdown]
# Pemesanan terbanyak dilakukan pada tanggal 24, 16, dan 15.

# %%
#Melihat perkembangan jumlah pesanan dan nilai total order dari bulan ke bulan
monthly_orders = all_joined_df.resample(rule='M', on='order_date').agg(count_order = ('order_id','nunique'), sum_order_value = ('total_order_value','sum')).reset_index()
monthly_orders = monthly_orders.rename(columns ={"order_date":"month_order"})
monthly_orders.month_order = monthly_orders.month_order.dt.strftime('%Y-%m')
monthly_orders
# Out:
#    month_order  count_order  sum_order_value
# 0      2016-09            2           279.69
# 1      2016-10          290         51354.52
# 2      2016-11            0             0.00
# 3      2016-12            1            19.62
# 4      2017-01          787        136943.46
# 5      2017-02         1718        283561.69
# 6      2017-03         2617        425617.96
# 7      2017-04         2377        405848.61
# 8      2017-05         3640        582710.83
# 9      2017-06         3205        499652.24
# 10     2017-07         3946        578753.73
# 11     2017-08         4272        661903.52
# 12     2017-09         4227        717102.72
# 13     2017-10         4547        764756.03
# 14     2017-11         7421       1172191.68
# 15     2017-12         5618        861526.77
# 16     2018-01         7187       1101920.01
# 17     2018-02         6624        979486.16
# 18     2018-03         7168       1152656.99
# 19     2018-04         6919       1156248.89
# 20     2018-05         6833       1145686.46
# 21     2018-06         6145       1020381.90
# 22     2018-07         6233       1039783.58
# 23     2018-08         6421        996973.51
# 24     2018-09            1           166.46

# %% [markdown]
# ## Explore geo_df

# %%
geo_df.sample(10)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 624078                        37062       -21.583844       -45.437784
# 525379                        28990       -22.930099       -42.556427
# 96613                          4567       -23.618193       -46.682767
# 545331                        30110       -19.913542       -43.931416
# 721522                        55750        -7.849167       -35.762137
# 799282                        74655       -16.649661       -49.250708
# 289202                        13025       -22.895737       -47.051312
# 601073                        35613       -19.522194       -45.789937
# 138620                         5756       -23.625668       -46.755065
# 468948                        24060       -22.884707       -43.110665
#
#          geolocation_city geolocation_state
# 624078           varginha                MG
# 525379          saquarema                RJ
# 96613           sao paulo                SP
# 545331     belo horizonte                MG
# 721522            surubim                PE
# 799282            goiânia                GO
# 289202           campinas                SP
# 601073  estrela do indaia                MG
# 138620          sao paulo                SP
# 468948            niteroi                RJ

# %%
import unidecode

def pretty_string(column):
    column_space = ' '.join(column.split())
    return unidecode.unidecode(column_space.lower())

# %% [markdown]
# pip install unicode

# %% [markdown]
# import unidecode

# %% [markdown]
# !pip install unidecode

# %%
geo_df['geolocation_city'] = geo_df['geolocation_city'].apply(pretty_string)

# %%
geo_df.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
geo_df[geo_df['geolocation_zip_code_prefix'] == 24220].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 470805                        24220       -22.905817       -43.106989
# 470811                        24220       -22.902306       -43.112545
# 470812                        24220       -22.904567       -43.110491
# 470820                        24220       -22.902575       -43.109192
# 470821                        24220       -22.907500       -43.106170
#
#        geolocation_city geolocation_state
# 470805          niteroi                RJ
# 470811          niteroi                RJ
# 470812          niteroi                RJ
# 470820          niteroi                RJ
# 470821          niteroi                RJ

# %% [markdown]
# ## Analisis RFM

# %% [markdown]
# ### Analisis RFM digunakan untuk segmentasi customer berdasarkan perilaku transaksi. Analisis RFM dilakukan berdasarkan parameter berikut
#
# ### 1. Recency (R) :
# ### Berapa lama sejak pelanggan terakhir melakukan pembelian.
# ### Nilai recency yang rendah menunjukkan pelanggan tersebut aktif melakukan pemesanan.
#
# ### 2. Frequency (F) :
# ### Berapa kali pelanggan telah melakukan pembelian dalam periode tertentu.
# ### Nilai frequency yang tinggi menunjukkan pelanggan tersebut sering melakukan pemesanan.
#
# ### 3. Monetary (M) :
# ### Berapa banyaj total uang yang dihabiskan oleh pelanggan.
# ### Nilai monetary yang tinggi menunjukkan pelanggan tersebut menghabiskan uang yang lebih banyak dalam transaksi.

# %%
#Membuat dataset bernama rfm_df untuk melakukan analisis RFM
rfm_df = all_joined_df.groupby(by="customer_unique_id", as_index=False).agg(
    max_order_date = ("order_date", "max"), # mengambil tanggal order terakhir pelanggan
    frequency = ("order_id", "nunique"), # menghitung jumlah order pelanggan
    monetary = ("total_order_value", "sum") # menghitung total jumlah uang yang telah dikeluarkan oleh pelanggan
    )

rfm_df['max_order_date'] = rfm_df['max_order_date'].dt.date #mengubah menjadi format tanggal
recent_order_date = all_joined_df['order_date'].dt.date.max() #memilih hari terakhir dalam kolom order_date
rfm_df.insert(1,'recency', rfm_df['max_order_date'].apply(lambda x: (recent_order_date - x).days)) #mencari selisih kapan terakhir kali pelanggan bertransaksi
rfm_df.drop('max_order_date', axis=1, inplace=True) #menghapus kolom yang tidak dibutuhkan
rfm_df.head(15)
# Out:
#                   customer_unique_id  recency  frequency  monetary
# 0   0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90
# 1   0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19
# 2   0000f46a3911fa3c0805444483337064      542          1     86.22
# 3   0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62
# 4   0004aac84e0df4da2b147fca70cf8255      293          1    196.89
# 5   0004bd2a26a76fe21f786e4fbd80607f      151          1    166.98
# 6   00050ab1314c0e55a6ca13cf7181fecf      136          1     35.38
# 7   00053a61a98854899e70ed204dd4bafe      187          1    419.18
# 8   0005e1862207bf6ccc02e4228effd9a0      548          1    150.12
# 9   0005ef4cd20d2893f0d9fbd94d3c0d97      175          1    129.76
# 10  0006fdc98a402fceb4eb0ee528f6a8d4      412          1     29.00
# 11  00082cbe03e478190aadbea78542e933      288          1    126.26
# 12  00090324bbad0e9342388303bb71ba0a      163          1     63.66
# 13  000949456b182f53c18b68d6babc79c1      133          1     82.05
# 14  000a5ad9c4601d2bbdd9ed765d5213b3      388          1     91.28

# %%
#Melihat deskripsi statistik rfm_df
rfm_df.describe()
# Out:
#             recency     frequency      monetary
# count  94983.000000  94983.000000  94983.000000
# mean     243.334197      1.033859    165.666772
# std      152.984601      0.210811    226.726478
# min        0.000000      1.000000      9.590000
# 25%      119.000000      1.000000     63.100000
# 50%      224.000000      1.000000    107.900000
# 75%      352.000000      1.000000    182.930000
# max      729.000000     16.000000  13664.080000

# %% [markdown]
# Terdapat sebanyak 94.983 pelanggan unik. Di antara semua pelanggan, ada yang bertransaksi terakhir paling lama 729 hari, lalu frekuensi berbelanja paling banyak 16 kali, serta melakukan order dengan nilai minimum order sebesar 9,59 Real dan nilai maksimum order sebesar 13.664,08 Real.

# %%
#Melihat pelanggan yang terakhir kali bertransaksi
rfm_df.sort_values(by='recency', ascending=True)
# Out:
#                      customer_unique_id  recency  frequency  monetary
# 94648  ff22e30958c13ffe219db7d711e8f564        0          2    332.92
# 67207  b4dcade04bc548b7e3b0243c801f8c26        5          1    106.95
# 45386  7a22d14aa3c3599238509ddca4b93b01        5          1     73.10
# 67999  b701bebbdf478f5500348f03aff62121        5          1     33.23
# 65345  afbcfd0b9c5233e7ccc73428526fbb52        5          1    497.25
# ...                                 ...      ...        ...       ...
# 50299  87776adb449c551e74c13fc34f036105      700          1     40.95
# 36463  61db744d2f835035a5625b59350c6b63      700          1     53.73
# 52320  8d3a54507421dbd2ce0a1d58046826e0      700          1    133.46
# 48745  830d5b7aaa3b6f1e9ad63703bec97d23      718          1    143.46
# 68297  b7d76e111c89f7ebf14761390f0f7d17      729          1    136.23
#
# [94983 rows x 4 columns]

# %%
#Melihat pelanggan yang paling sering order
rfm_df.sort_values(by='frequency', ascending=False)
# Out:
#                      customer_unique_id  recency  frequency  monetary
# 52352  8d50f5eadf50201ccdcedfb9e2ac8455       14         16    902.04
# 23198  3e43e6105506432c953e165fb2acf44c      188          9   1172.67
# 75205  ca77025e7201e3b30c44b472ff346268       94          7   1122.72
# 37370  6469f99c1f9dfae7733b25662e7f1782       67          7    758.83
# 10234  1b6c7548a2a1f9037c1fd3ddfed95f33      201          7    959.01
# ...                                 ...      ...        ...       ...
# 32120  5650c85bcdef051d8bc16e0771747686      266          1     69.73
# 32119  5650bf668868651d51740cd49908814e       61          1     14.29
# 32118  56509f7bc43892a0da09ee14f50a6f84      230          1    211.89
# 32117  564feb90710b4f84399f931fa97ea704      518          1    330.27
# 94982  ffffd2657e2aad2907e67c3e9daecbeb      489          1     71.56
#
# [94983 rows x 4 columns]

# %%
#Melihat pelanggan yang menghabiskan uang paling banyak untuk order
rfm_df.sort_values(by='monetary', ascending=False)
# Out:
#                      customer_unique_id  recency  frequency  monetary
# 3788   0a0a92112bd4c708ca5fde585afaa872      339          1  13664.08
# 81011  da122df9eeddfedc1dc1f5349a1a690c      520          2   7571.63
# 43938  763c8b1c9c68a0229c42c9fc6f662b93       50          1   7274.88
# 81850  dc4802a71eae9be1dd28f5d788ceb526      568          1   6929.31
# 25901  459bef486812aa25204be022145caa62       40          1   6922.21
# ...                                 ...      ...        ...       ...
# 15062  2878e5b88167faab17d4fb83a986d38b      309          1     11.63
# 41420  6f5b9d1cdccc4d28f0483a612edecacf      366          1     11.63
# 66604  b33336f46234b24a613ad9064d13106d       74          1     10.89
# 70229  bd06ce0e06ad77a7f681f1a4960a3cc6      355          1     10.07
# 18435  317cfc692e3f86c45c95697c61c853a6        9          1      9.59
#
# [94983 rows x 4 columns]

# %% [markdown]
# # Visualization & Explanatory Analysis

# %%
#Membuat fungsi untuk memberikan warna tertentu pada data dengan nilai maksimum
def set_custom_palette(series, max_color = '#3187d4', other_color = '#b3bcc4'):
    max_value = series.max()
    pal = []

    for item in series:
        if item == max_value:
            pal.append(max_color)
        else:
            pal.append(other_color)
    return pal

# %% [markdown]
# ### Kategori produk apa saja yang paling banyak dan yang paling sedikit dipesan?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))

colors = ["#3187d4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4"]
sns.barplot(
    x="num_of_order",
    y="product_category",
    data= order_by_product_category.sort_values(by=['num_of_order','sum_order_value'], ascending=False).head(10),
    palette=colors,
    ax=ax[0]
    )
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Paling Banyak Dipesan", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(
    x="num_of_order",
    y="product_category",
    data= order_by_product_category.sort_values(by=['num_of_order','sum_order_value'], ascending=True).head(10),
    palette=colors,
    ax=ax[1]
    )
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Paling Sedikit Dipesan", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
plt.suptitle("Kategori Produk yang Paling Banyak dan Paling Sedikit Dipesan", fontsize=20)
plt.show()

# %% [markdown]
# Kategori produk yang paling banyak dipesan yaitu Bed Bath Table, sebaliknya yaitu Security and Services yang paling sedikit dipesan.

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))

colors = ["#3187d4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4"]
sns.barplot(
    x="sum_order_value",
    y="product_category",
    data= order_by_product_category.sort_values(by='sum_order_value', ascending=False).head(10),
    palette=colors,
    ax=ax[0]
    )
ax[0].set_ylabel(None)
ax[0].set_xlabel('Total Nilai Order (Juta R$)', fontsize=12)
ax[0].set_title("Total Nilai Order Tertinggi", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(
    x="sum_order_value",
    y="product_category",
    data= order_by_product_category.sort_values('sum_order_value', ascending=True).head(10),
    palette=colors,
    ax=ax[1]
    )
ax[1].set_ylabel(None)
ax[1].set_xlabel('Total Nilai Order (R$)', fontsize=12)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Total Nilai Order Terendah", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
plt.suptitle("Kategori Produk dengan Total Nilai Order Tertinggi dan Terendah", fontsize=20)
plt.show()

# %% [markdown]
# Kategori produk yang memiliki total nilai order tertinggi yaitu Health Beauty, sebaliknya yaitu Security and Services yang memiliki total nilai order terendah.

# %% [markdown]
# ### Bagaimana segmentasi pada pelanggan berdasarkan Recency (R), Frequency (F), dan Monetary(M)?

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(28, 8))
colors = ["#3187d4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4"]

sns.barplot(x="customer_unique_id", y="recency", data= rfm_df.sort_values(by='recency', ascending=True).head(10), palette=colors, ax=ax[0])
ax[0].set_ylabel('Hari', fontsize=12)
ax[0].set_xlabel(None)
ax[0].set_title("Berdasarkan Recency", loc="center", fontsize=16)
ax[0].tick_params(axis ='y', labelsize=15)
ax[0].set_xticklabels(ax[0].get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=14)

sns.barplot(x="customer_unique_id", y="frequency", data= rfm_df.sort_values(by='frequency', ascending=False).head(10), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("Berdasarkan Frequency", loc="center", fontsize=16)
ax[1].tick_params(axis='y', labelsize=15)
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=14)

sns.barplot(x="customer_unique_id", y="monetary", data= rfm_df.sort_values(by='monetary', ascending=False).head(10), palette=colors, ax=ax[2])
ax[2].set_ylabel('R$', fontsize=12)
ax[2].set_xlabel(None)
ax[2].set_title("Berdasarkan Monetary", loc="center", fontsize=16)
ax[2].tick_params(axis ='y', labelsize=15)
ax[2].set_xticklabels(ax[2].get_xticklabels(), rotation=45, horizontalalignment='right', fontsize=14)

plt.suptitle("Pelanggan Terbaik Berdasarkan Parameter RFM", fontsize=20)
plt.show()

# %% [markdown]
# Pengelompokkan pelanggan terbaik dapat dilihat dari grafik di atas bahwa
# Recency : pelanggan dengan ID ff22e30958c13ffe219db7d711e8f564
# Frequency : pelanggan dengan ID 8d50f5eadf50201ccdcedfb9e2ac8455
# Monetary : pelanggan dengan ID 0a0a92112bd4c708ca5fde585afaa872.

# %%
#Memberikan ranking pada pelanggan berdasarkan skor Recency(R), Frequency(F), dan Monetary(M)
rfm_df['R_rank'] = rfm_df['recency'].rank(ascending=False)
rfm_df['F_rank'] = rfm_df['frequency'].rank(ascending=True)
rfm_df['M_rank'] = rfm_df['monetary'].rank(ascending=True)

#Normalisasi ranking pelanggan
rfm_df['R_rank_norm'] = (rfm_df['R_rank']/rfm_df['R_rank'].max())*100
rfm_df['F_rank_norm'] = (rfm_df['F_rank']/rfm_df['F_rank'].max())*100
rfm_df['M_rank_norm'] = (rfm_df['F_rank']/rfm_df['M_rank'].max())*100

rfm_df.drop(columns=['R_rank', 'F_rank', 'M_rank'], inplace=True)
rfm_df.head(10)
# Out:
#                  customer_unique_id  recency  frequency  monetary  RFM_Score  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90       2.63
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19       2.62
# 2  0000f46a3911fa3c0805444483337064      542          1     86.22       2.09
# 3  0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62       2.28
# 4  0004aac84e0df4da2b147fca70cf8255      293          1    196.89       2.31
# 5  0004bd2a26a76fe21f786e4fbd80607f      151          1    166.98       2.57
# 6  00050ab1314c0e55a6ca13cf7181fecf      136          1     35.38       2.59
# 7  00053a61a98854899e70ed204dd4bafe      187          1    419.18       2.50
# 8  0005e1862207bf6ccc02e4228effd9a0      548          1    150.12       2.08
# 9  0005ef4cd20d2893f0d9fbd94d3c0d97      175          1    129.76       2.52
#
#    R_rank_norm  F_rank_norm  M_rank_norm
# 0    76.165735    48.480781    48.480781
# 1    75.137656    48.480781    48.480781
# 2     3.562743    48.480781    48.480781
# 3    28.749882    48.480781    48.480781
# 4    33.756041    48.480781    48.480781
# 5    67.423118    48.480781    48.480781
# 6    70.942169    48.480781    48.480781
# 7    58.751040    48.480781    48.480781
# 8     3.059495    48.480781    48.480781
# 9    61.696830    48.480781    48.480781

# %%
#Membuat RFM Score dengan weighted value
rfm_df['RFM_Score'] = 0.15*rfm_df['R_rank_norm'] + 0.28 *rfm_df['F_rank_norm'] + 0.57*rfm_df['M_rank_norm'] #Weighting pada masing-masing parameter
rfm_df['RFM_Score'] = (0.05*rfm_df['RFM_Score']).round(2) #Mengubah nilai RFM Score menjadi nilai dengan maksimal 5 dan membulatkannya hingga 2 desimal

rfm_df = rfm_df[['customer_unique_id', 'recency',	'frequency',	'monetary',	'RFM_Score']]
rfm_df.head()
# Out:
#                  customer_unique_id  recency  frequency  monetary  RFM_Score
# 0  0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90       2.63
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19       2.62
# 2  0000f46a3911fa3c0805444483337064      542          1     86.22       2.09
# 3  0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62       2.28
# 4  0004aac84e0df4da2b147fca70cf8255      293          1    196.89       2.31

# %%
#Memberikan rating pada pelanggan berdasarkan RFM Score
'''
RFM Score > 4.5 : Top Customer
4.5 > RFM Score > 4 : High Value Customer
4> RFM Score > 3 : Medium Value Customer
3> RFM Score > 1.6 : Low Value Customer
RFM Score <1.6 : Lost Customer
'''
rfm_df["customer_segment"] = np.where(
    rfm_df['RFM_Score'] > 4.5, "Top Customer", (np.where(
        rfm_df['RFM_Score'] > 4, "High Value Customer",(np.where(
            rfm_df['RFM_Score'] > 3, "Medium Value Customer", np.where(
                rfm_df['RFM_Score'] > 1.6, 'Low Value Customer', 'Lost Customer')))))
)

rfm_df.head(15)
# Out:
# C:\Users\Fifi\AppData\Local\Temp\ipykernel_25484\1269590980.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_df["customer_segment"] = np.where(
#                   customer_unique_id  recency  frequency  monetary  RFM_Score  \
# 0   0000366f3b9a7992bf8c76cfdf3221e2      116          1    141.90       2.63
# 1   0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     27.19       2.62
# 2   0000f46a3911fa3c0805444483337064      542          1     86.22       2.09
# 3   0000f6ccb0745a6a4b88665a16c9f078      326          1     43.62       2.28
# 4   0004aac84e0df4da2b147fca70cf8255      293          1    196.89       2.31
# 5   0004bd2a26a76fe21f786e4fbd80607f      151          1    166.98       2.57
# 6   00050ab1314c0e55a6ca13cf7181fecf      136          1     35.38       2.59
# 7   00053a61a98854899e70ed204dd4bafe      187          1    419.18       2.50
# 8   0005e1862207bf6ccc02e4228effd9a0      548          1    150.12       2.08
# 9   0005ef4cd20d2893f0d9fbd94d3c0d97      175          1    129.76       2.52
# 10  0006fdc98a402fceb4eb0ee528f6a8d4      412          1     29.00       2.19
# 11  00082cbe03e478190aadbea78542e933      288          1    126.26       2.32
# 12  00090324bbad0e9342388303bb71ba0a      163          1     63.66       2.55
# 13  000949456b182f53c18b68d6babc79c1      133          1     82.05       2.60
# 14  000a5ad9c4601d2bbdd9ed765d5213b3      388          1     91.28       2.21
#
#       customer_segment
# 0   Low Value Customer
# 1   Low Value Customer
# 2   Low Value Customer
# 3   Low Value Customer
# 4   Low Value Customer
# 5   Low Value Customer
# 6   Low Value Customer
# 7   Low Value Customer
# 8   Low Value Customer
# 9   Low Value Customer
# 10  Low Value Customer
# 11  Low Value Customer
# 12  Low Value Customer
# 13  Low Value Customer
# 14  Low Value Customer

# %%
#Melihat Pembagian Segmen Pelanggan Berdasarkan RFM Score
rfm_df.customer_segment.value_counts()
# Out:
# customer_segment
# Low Value Customer     92096
# Top Customer            1767
# High Value Customer     1120
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,10))
plt.pie(
    rfm_df.customer_segment.value_counts(),
    labels= rfm_df.customer_segment.value_counts().index,
    autopct= '%1.2f%%',
    explode = [0.3, 0.5, 0],
    colors= sns.color_palette('Set1')
)
plt.title("Segmentasi Pelanggan Berdasarkan Score RFM", loc='center', fontsize=20)
plt.show()

# %% [markdown]
# Berdasarkan hasil analisis RFM, sebagian besar pelanggan berada pada segmen Low Value Customer dengan persentase sebesar 96,96%, yang sisanya diikuti oleh pelanggan Top Customer dan High Value Customer.

# %%
#Melihat pelanggan yang memiliki RFM Score dan Monetary Score tertinggi
rfm_df.sort_values(by=['RFM_Score', 'monetary'],ascending=False).head(10)
# Out:
#                      customer_unique_id  recency  frequency  monetary  \
# 81925  dc813062e0fc23409cd255f7f53c7074       11          6   1033.62
# 52352  8d50f5eadf50201ccdcedfb9e2ac8455       14         16    902.04
# 92332  f8bc1d81f395f6239a2a5ab1b9edf1ab       14          3    515.10
# 58244  9cc5a07f169a1606fd347a56683e6ea6       12          4    419.25
# 45118  795c1622cf7a53d63d324e862349d01c       17          4    354.23
# 81851  dc48b0a1b0e6abb6586f322c189f6b93       14          3    327.39
# 19638  34b0cd95480e55c2a701293a2b9671b3        6          3    295.57
# 85151  e53fd5575f1418397aae732c5755b6fc       14          3    132.03
# 83403  e0836a97eaae86ac4adc26fbb334a527        7          3     88.27
# 29646  4facc2e6fbc2bffab2fea92d2b4aa7e4       21          4   1760.75
#
#        RFM_Score customer_segment
# 81925       5.00     Top Customer
# 52352       4.99     Top Customer
# 92332       4.99     Top Customer
# 58244       4.99     Top Customer
# 45118       4.99     Top Customer
# 81851       4.99     Top Customer
# 19638       4.99     Top Customer
# 85151       4.99     Top Customer
# 83403       4.99     Top Customer
# 29646       4.98     Top Customer

# %%
fig, ax = plt.subplots(figsize=(10, 8))

colors = ["#3187d4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4", "#b3bcc4"]

sns.barplot(x="RFM_Score", y="customer_unique_id", data= rfm_df.sort_values(by=['RFM_Score', 'monetary'],ascending=False).head(10), palette=colors)
ax.set_ylabel(None)
ax.set_xlabel('RFM Score', fontsize=14)
ax.set_title("Pelanggan Terbaik Berdasarkan RFM Score", loc="center", fontsize=15)
ax.bar_label(ax.containers[0], label_type='center')
ax.tick_params(axis ='y', labelsize=10)

# %% [markdown]
# Pelanggan dengan ID dc813062e0fc23409cd255f7f53c7074 merupakan pelanggan terbaik yang memiliki RFM Score yang tertinggi

# %% [markdown]
# ## Dimana letak geografis yang memiliki customer terbanyak?

# %%
other_state_geolocation = geo_df.groupby(['geolocation_zip_code_prefix'])['geolocation_state'].nunique().reset_index(name='count')
other_state_geolocation[other_state_geolocation['count']>= 2].shape
max_state = geo_df.groupby(['geolocation_zip_code_prefix','geolocation_state']).size().reset_index(name='count').drop_duplicates(subset = 'geolocation_zip_code_prefix').drop('count',axis=1)

# %%
geolocation_silver = geo_df.groupby(['geolocation_zip_code_prefix','geolocation_city','geolocation_state'])[['geolocation_lat','geolocation_lng']].median().reset_index()
geolocation_silver = geolocation_silver.merge(max_state,on=['geolocation_zip_code_prefix','geolocation_state'],how='inner')

# %%
customers_silver = customers_df.merge(geolocation_silver,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')

# %%
customers_silver.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  5dca924cc99eea2dc5ba40d11ec5dd0f  2761fee7f378f0a8d7682d8a3fa07ab1
# 2  661897d4968f1b59bfff74c7eb2eb4fc  d06a495406b79cb8203ea21cc0942f8c
# 3  702b62324327ccba20f1be3465426437  8b3d988f330c1d1c3332ccd440c147b7
# 4  bdf997bae7ca819b0415f5174d6b4302  866755e25db620f8d7e81b351a15bb2f
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#    geolocation_zip_code_prefix geolocation_city geolocation_state  \
# 0                        14409           franca                SP
# 1                        14409           franca                SP
# 2                        14409           franca                SP
# 3                        14409           franca                SP
# 4                        14409           franca                SP
#
#    geolocation_lat  geolocation_lng
# 0        -20.50207       -47.396822
# 1        -20.50207       -47.396822
# 2        -20.50207       -47.396822
# 3        -20.50207       -47.396822
# 4        -20.50207       -47.396822

# %%
customers_silver.to_csv("geolocation.csv", index=False)

# %%
import matplotlib.image as mpimg
import urllib.request

def plot_brazil_map(data):
    brazil = mpimg.imread(urllib.request.urlopen('https://i.pinimg.com/originals/3a/0c/e1/3a0ce18b3c842748c255bc0aa445ad41.jpg'),'jpg')
    ax = data.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='blue')
    plt.axis('off')
    plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
    plt.show()

# %%
plot_brazil_map(customers_silver.drop_duplicates(subset='customer_unique_id'))

# %% [markdown]
# Banyak customer yang berasal dari negara bagian tenggara dan selatan.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Question 1 : Kategori produk apa saja yang paling banyak dan yang paling sedikit dipesan?

# %% [markdown]
# Berdasarkan jumlah ordernya, kategori produk yang paling banyak dipesan yaitu Bed Bath Table, Health Beauty, dan Sports Leisure, sedangkan yang paling sedikit dipesan yaitu Security and Services, Pc Gaming, dan Fashion Childrens Clothes.
#
# Berdasarkan total nilai ordernya, kategori produk dengan total nilai order tertinggi yaitu Health Beauty, Watches Gifts, dan Bed Bath Table, sedangkan kategori produk dengan total nilai order terendah yaitu Security and Services, Fashion Childrens Clothes, dan Cds Dvds Musicals.

# %% [markdown]
# ## Question 2 : Bagaimana segmentasi pada pelanggan berdasarkan Recency (R), Frequency (F), dan Monetary(M)?

# %% [markdown]
# Berdasarkan hasil analisis RFM di atas, pelanggan terbaik menurut RFM Score tertinggi yaitu pelanggan dengan ID dc813062e0fc23409cd255f7f53c7074.
#
# Segmentasi pelanggan dilihat dari kapan terakhir order (Recency), frekuensi order (Frequency), dan total nilai order (Monetary), dimana terdapat 96,96% pelanggan yang tergolong ke dalam segmen Low Value Customer, 1,86% pelanggan tergolong ke dalam segmen Top Customer, dan sebanyak 1,18% pelanggan tergolong ke dalam segmen High Value Customer dari total pelanggan sebanyak 94.983 pelanggan.

# %% [markdown]
# ## Question 3 : Dimana letak geografis yang memiliki customer terbanyak?

# %% [markdown]
# Negara bagian yang memiliki customer terbanyak adalah Sao Paulo. Pada bagian Explanatory Analysis berfokus pada peta Brazil. Ditemukan bahwa ada lebih banyak customer di bagian tenggara dan selatan. Informasi lainnya, ada lebih banyak customer di kota-kota yang merupakan ibu kota seperti São Paulo, Rio de Janeiro, Porto Alegre, dll.

# %%
# Ambil Data yang sudah melalui tahap cleaning data
all_joined_df.to_csv('main_data_for_dashboard.csv', index=False)
